# %%
# First, import the required libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Define the plotting function
def plot_distributions(df, columns):
    plt.figure(figsize=(15, 6))
    sns.violinplot(data=df[columns])
    plt.xticks(rotation=45)
    plt.title('Feature Distributions After Scaling')
    plt.tight_layout()
    plt.show()

# Now call the function with your scaled data and numerical columns
# Using your numerical columns
numerical_cols = ['avg_global_active_power', 'avg_global_reactive_power', 
                 'avg_global_intensity']

# Plot distributions for training data
print("Training Data Distributions:")
plot_distributions(train_df, numerical_cols)

# Plot distributions for validation data
print("\nValidation Data Distributions:")
plot_distributions(val_df, numerical_cols)

# Plot distributions for test data
print("\nTest Data Distributions:")
plot_distributions(test_df, numerical_cols)

# You can also compare before and after scaling
# Before scaling
print("\nBefore Scaling:")
plot_distributions(train_df, numerical_cols)

# After scaling
print("\nAfter Scaling:")
plot_distributions(train_scaled, numerical_cols)

# %%
# First, import the required libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Define the plotting function
def plot_distributions(df, columns):
    plt.figure(figsize=(15, 6))
    sns.violinplot(data=df[columns])
    plt.xticks(rotation=45)
    plt.title('Feature Distributions After Scaling')
    plt.tight_layout()
    plt.show()

# Now call the function with your scaled data and numerical columns
# Using your numerical columns
numerical_cols = ['avg_global_active_power', 'avg_global_reactive_power', 
                 'avg_global_intensity']

# Plot distributions for training data
print("Training Data Distributions:")
plot_distributions(train_df, numerical_cols)

# Plot distributions for validation data
print("\nValidation Data Distributions:")
plot_distributions(val_df, numerical_cols)

# Plot distributions for test data
print("\nTest Data Distributions:")
plot_distributions(test_df, numerical_cols)

# You can also compare before and after scaling
# Before scaling
print("\nBefore Scaling:")
plot_distributions(train_df, numerical_cols)

# After scaling
print("\nAfter Scaling:")
plot_distributions(train_scaled, numerical_cols)
